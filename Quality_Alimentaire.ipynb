# %% [markdown]
# # Rapport sur la qualité des produits alimentaires

# %%
# Import de la librairie Pandas numpy
import pandas as pd
import numpy as np
# Import de la librairie matplotlib
import matplotlib.pyplot as plt

Agriculture_biologique = pd.read_csv('Agriculture_biologique_final.csv',sep='\t')

Impact_environnemental = pd.read_csv('Impact environnemental_final.csv',sep='\t', low_memory=False)

Qualite_nutritionnelle = pd.read_csv('Qualite nutritionnelle_final.csv',sep='\t', low_memory=False)

# %%
Agriculture_biologique.head()
# Out:
#                    product_name              brands_tags serving_size  est_bio
# 0                          Skyr                   danone          NaN    False
# 1   moutarde au moût de raisin             courte-paille          NaN    False
# 2        Solène céréales poulet                    crous          NaN    False
# 3            Tarte noix de coco        crous-resto,crous          NaN    False
# 4        Crème dessert chocolat  ferme-de-la-fremondiere          NaN    False

# %%
Impact_environnemental.head()
# Out:
#                    code                  product_name quantity    brands_tags  \
# 0  00000000000026772226                          Skyr    480 g         danone
# 1         0000000000017              Vitória crackers      NaN            NaN
# 2         0000000000031                         Cacao    130 g            NaN
# 3         0000000000100   moutarde au moût de raisin      100g  courte-paille
# 4         0000000000123         Sauce Sweety chili 0%      NaN            NaN
#
#   countries_tags serving_size  \
# 0      en:france          NaN
# 1      en:france          NaN
# 2      en:france          NaN
# 3      en:france          NaN
# 4      en:france          NaN
#
#                                            image_url ecoscore_grade  \
# 0  https://images.openfoodfacts.org/images/produc...              d
# 1  https://images.openfoodfacts.org/images/produc...        unknown
# 2  https://images.openfoodfacts.org/images/produc...        unknown
# ...

# %%
Qualite_nutritionnelle.head()
# Out:
#                    code                  product_name quantity    brands_tags  \
# 0  00000000000026772226                          Skyr    480 g         danone
# 1         0000000000017              Vitória crackers      NaN            NaN
# 2         0000000000031                         Cacao    130 g            NaN
# 3         0000000000100   moutarde au moût de raisin      100g  courte-paille
# 4         0000000000123         Sauce Sweety chili 0%      NaN            NaN
#
#   countries_tags serving_size  \
# 0      en:france          NaN
# 1      en:france          NaN
# 2      en:france          NaN
# 3      en:france          NaN
# 4      en:france          NaN
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
# ...

# %%
Agriculture_biologique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463922 entries, 0 to 463921
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   product_name  456563 non-null  object
#  1   brands_tags   463922 non-null  object
#  2   serving_size  86178 non-null   object
#  3   est_bio       463922 non-null  bool
# dtypes: bool(1), object(3)
# memory usage: 11.1+ MB

# %%
Impact_environnemental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932866 entries, 0 to 932865
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   code            932866 non-null  object
#  1   product_name    907007 non-null  object
#  2   quantity        279260 non-null  object
#  3   brands_tags     463922 non-null  object
#  4   countries_tags  932866 non-null  object
#  5   serving_size    89842 non-null   object
#  6   image_url       842701 non-null  object
#  7   ecoscore_grade  931887 non-null  object
#  8   est_plastique   932866 non-null  bool
#  9   est_palm        932866 non-null  bool
#  10  est_cocoa       932866 non-null  bool
# dtypes: bool(3), object(8)
# memory usage: 59.6+ MB

# %%
Qualite_nutritionnelle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932866 entries, 0 to 932865
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   code                932866 non-null  object
#  1   product_name        907007 non-null  object
#  2   quantity            279260 non-null  object
#  3   brands_tags         463922 non-null  object
#  4   countries_tags      932866 non-null  object
#  5   serving_size        89842 non-null   object
#  6   image_url           842701 non-null  object
#  7   ingredients_tags    259155 non-null  object
#  8   nutriscore_grade    319615 non-null  object
#  9   energy-kcal_100g    686843 non-null  float64
#  10  fat_100g            703194 non-null  float64
#  11  saturated-fat_100g  708835 non-null  float64
#  12  sugars_100g         708136 non-null  float64
#  13  proteins_100g       705019 non-null  float64
#  14  salt_100g           676852 non-null  float64
# ...

# %%
Agriculture_biologique.describe(include = 'all')
# Out:
#        product_name brands_tags serving_size est_bio
# count        456563      463922        86178  463922
# unique       311711       58298         9267       2
# top           Comté   carrefour      serving   False
# freq            468       12445        10326  393476

# %%
Impact_environnemental.describe(include = 'all')
# Out:
#                  code product_name quantity brands_tags countries_tags  \
# count          932866       907007   279260      463922         932866
# unique         843234       551132    22829       58298           1812
# top     3700009201312        Comté    500 g   carrefour      en:france
# freq                3         1050    12890       12445         877139
#
#        serving_size                                          image_url  \
# count         89842                                             842701
# unique         9708                                             772312
# top         serving  https://images.openfoodfacts.org/images/produc...
# freq          10907                                                 35
#
#        ecoscore_grade est_plastique est_palm est_cocoa
# count          931887        932866   932866    932866
# unique              7             2        2         2
# top           unknown         False    False     False
# ...

# %%
Qualite_nutritionnelle.describe(include = 'all')
# Out:
#                  code product_name quantity brands_tags countries_tags  \
# count          932866       907007   279260      463922         932866
# unique         843234       551132    22829       58298           1812
# top     3700009201312        Comté    500 g   carrefour      en:france
# freq                3         1050    12890       12445         877139
# mean              NaN          NaN      NaN         NaN            NaN
# std               NaN          NaN      NaN         NaN            NaN
# min               NaN          NaN      NaN         NaN            NaN
# 25%               NaN          NaN      NaN         NaN            NaN
# 50%               NaN          NaN      NaN         NaN            NaN
# 75%               NaN          NaN      NaN         NaN            NaN
# max               NaN          NaN      NaN         NaN            NaN
#
#        serving_size                                          image_url  \
# ...

# %%
Agriculture_biologique.isna().sum()
# Out:
# product_name      7359
# brands_tags          0
# serving_size    377744
# est_bio              0
# dtype: int64

# %%
Impact_environnemental.isna().sum()
# Out:
# code                   0
# product_name       25859
# quantity          653606
# brands_tags       468944
# countries_tags         0
# serving_size      843024
# image_url          90165
# ecoscore_grade       979
# est_plastique          0
# est_palm               0
# est_cocoa              0
# dtype: int64

# %%
Qualite_nutritionnelle.isna().sum()
# Out:
# code                       0
# product_name           25859
# quantity              653606
# brands_tags           468944
# countries_tags             0
# serving_size          843024
# image_url              90165
# ingredients_tags      673711
# nutriscore_grade      613251
# energy-kcal_100g      246023
# fat_100g              229672
# saturated-fat_100g    224031
# sugars_100g           224730
# proteins_100g         227847
# salt_100g             256014
# nb_nocif                   0
# dtype: int64

# %% [markdown]
# ## Enlever les doublons dans les tables

# %%
Agriculture_biologique.duplicated().sum()
Agriculture_biologique_drop = Agriculture_biologique.drop_duplicates()
Agriculture_biologique_drop
# Out:
#                                product_name              brands_tags  \
# 0                                      Skyr                   danone
# 1               moutarde au moût de raisin             courte-paille
# 2                    Solène céréales poulet                    crous
# 3                        Tarte noix de coco        crous-resto,crous
# 4                    Crème dessert chocolat  ferme-de-la-fremondiere
# ...                                     ...                      ...
# 463912                 Nutra'cake framboise                  delical
# 463915              Chocolat noir patissier             monoprix-bio
# 463917                       Saveur ABRICIT                   gerble
# 463918                Lindt pâte à tartiner                    lindt
# 463919  Biodrink antioxydant pendant effort              punch-power
#
#        serving_size  est_bio
# 0               NaN    False
# 1               NaN    False
# 2               NaN    False
# ...

# %%
Impact_environnemental.duplicated().sum()
Impact_environnemental_drop = Impact_environnemental.drop_duplicates()
Impact_environnemental_drop
# Out:
#                         code                  product_name quantity  \
# 0       00000000000026772226                          Skyr    480 g
# 1              0000000000017              Vitória crackers      NaN
# 2              0000000000031                         Cacao    130 g
# 3              0000000000100   moutarde au moût de raisin      100g
# 4              0000000000123         Sauce Sweety chili 0%      NaN
# ...                      ...                           ...      ...
# 932859         9999991087217  Pastilles à l'eau de lourdes      NaN
# 932860         9999991950191                 Pain d’epices      NaN
# 932861         9999991953895              Crème de Marrons      NaN
# 932862         9999992756068                   Steak haché    500 g
# 932863         9999992756112                   Steak haché     1 kg
#
#           brands_tags countries_tags serving_size  \
# 0              danone      en:france          NaN
# ...

# %%
Qualite_nutritionnelle.duplicated().sum()
Qualite_nutritionnelle_drop = Qualite_nutritionnelle.drop_duplicates()
Qualite_nutritionnelle_drop
# Out:
#                         code                  product_name quantity  \
# 0       00000000000026772226                          Skyr    480 g
# 1              0000000000017              Vitória crackers      NaN
# 2              0000000000031                         Cacao    130 g
# 3              0000000000100   moutarde au moût de raisin      100g
# 4              0000000000123         Sauce Sweety chili 0%      NaN
# ...                      ...                           ...      ...
# 932859         9999991087217  Pastilles à l'eau de lourdes      NaN
# 932860         9999991950191                 Pain d’epices      NaN
# 932861         9999991953895              Crème de Marrons      NaN
# 932862         9999992756068                   Steak haché    500 g
# 932863         9999992756112                   Steak haché     1 kg
#
#           brands_tags countries_tags serving_size  \
# 0              danone      en:france          NaN
# ...

# %% [markdown]
# # Nettoyage des champs en erreur
# Chercher les champs avec des chaînes de caractères accentuées, des valeurs aberantes, des unités non standardisées...

# %%
#cols = Agriculture_biologique_drop.select_dtypes(include=[object]).columns
#Agriculture_biologique_drop[cols] = Agriculture_biologique_drop[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
#Agriculture_biologique_drop
#cols = Impact_environnemental_drop.select_dtypes(include=[object]).columns
#Impact_environnemental_drop[cols] = Impact_environnemental_drop[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
#Impact_environnemental_drop
#cols = Qualite_nutritionnelle_drop.select_dtypes(include=[object]).columns
#Qualite_nutritionnelle_drop[cols] = Qualite_nutritionnelle_drop[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
#Qualite_nutritionnelle_drop



#Agriculture_biologique_drop['email'].duplicated(keep=False)
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_10696\3664257643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Agriculture_biologique_drop[cols] = Agriculture_biologique_drop[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_10696\3664257643.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#code_corrige =[]
#for i in Impact_environnemental_drop['code']:
    #if len(i) < 13:
        #i = i.zfill(13)
    #elif len(i) > 13:
        #i = i.lstrip('0').zfill(13)
    #else:
        #i = i
    #code_corrige.append(i)   
    
#Impact_environnemental_drop ["code_corr"] = code_corrige

# %%
#Impact_environnemental_drop

# %%
#for i in Qualite_nutritionnelle_drop['code']:
    #if len(i) < 13:
        #i = i.zfill(13)
    #elif len(i) > 13:
        #i = i.lstrip('0').zfill(13)
    #else:
        #i = i
#Qualite_nutritionnelle_drop

# %%
# Mettre la valeur unknown pour toutes les valeurs manquantes dans les dataframes

mask_Agriculture_biologique_drop = Agriculture_biologique_drop['serving_size'].isnull()
Agriculture_biologique_drop.loc[mask_Agriculture_biologique_drop, 'serving_size'] = 'unknown'
#Agriculture_biologique_drop

mask_Impact_environnemental_drop = Impact_environnemental_drop['quantity'].isnull()
Impact_environnemental_drop.loc[mask_Impact_environnemental_drop, 'quantity'] = 'unknown'
mask_Impact_environnemental_drop = Impact_environnemental_drop['brands_tags'].isnull()
Impact_environnemental_drop.loc[mask_Impact_environnemental_drop, 'brands_tags'] = 'unknown'
mask_Impact_environnemental_drop = Impact_environnemental_drop['serving_size'].isnull()
Impact_environnemental_drop.loc[mask_Impact_environnemental_drop, 'serving_size'] = 'unknown'
#Impact_environnemental_drop

mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['quantity'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'quantity'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['brands_tags'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'brands_tags'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['serving_size'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'serving_size'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['ingredients_tags'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'ingredients_tags'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['nutriscore_grade'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'nutriscore_grade'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['energy-kcal_100g'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'energy-kcal_100g'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['fat_100g'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'fat_100g'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['saturated-fat_100g'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'saturated-fat_100g'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['sugars_100g'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'sugars_100g'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['proteins_100g'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'proteins_100g'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['salt_100g'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'salt_100g'] = 'unknown'
mask_Qualite_nutritionnelle_drop = Qualite_nutritionnelle_drop['nb_nocif'].isnull()
Qualite_nutritionnelle_drop.loc[mask_Qualite_nutritionnelle_drop, 'nb_nocif'] = 'unknown'
#Qualite_nutritionnelle_drop

# %%
# Les valeurs dans quantity sont des chaine de caractères dont les unités sont différentes nous choissons de les mettre en g
#Impact_environnemental_drop=Impact_environnemental_drop.rename(columns={'quantity': 'quantity_g'})
#Qualite_nutritionnelle_drop=Qualite_nutritionnelle_drop.rename(columns={'quantity': 'quantity_g'})
#for i in Impact_environnemental_drop['quantity_g']:
    #i=i.replace(" ", "")
    #Impact_environnemental_drop=Impact_environnemental_drop.iloc(i,'quantity_g')
    #Impact_environnemental_drop['quantity_g']

# %% [markdown]
# ## Jointures sur les tables
# 1_Table Agriculture_biologique_drop jointe à la table Impact_environnemental_drop

# %%
#df_final = pd.merge(Agriculture_biologique_drop,Impact_environnemental_drop, on = 'id_prod', how= 'outer', indicator = True)

# %%
df_merged1 = pd.merge(Impact_environnemental_drop, Qualite_nutritionnelle_drop)
df_merged2 = pd.merge(df_merged1, Agriculture_biologique_drop)

# %% [markdown]
# # Quelles sont les marques qui jouent le jeu et affichent l'ecosore ? Lesquelles ne le font pas?

# %%
#On recherche dans le dataframe Impact_environnemental_drop la colonne ecoscore_grade, les brands_tags qui affiche une note et celle pour qui la note est unknown

Impact_environnemental_drop[Impact_environnemental_drop.ecoscore_grade.isin(['unknown'])]
